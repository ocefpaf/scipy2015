# %%
import time

start_time = time.time()

# %%
# %load_ext watermark
# %watermark --githash --machine --python --packages iris,pyoos,owslib
# Out:
# CPython 2.7.9
# IPython 2.4.1
#
# iris 1.8.0.dev0
# pyoos 0.6.2
# owslib 0.8.13
#
# compiler   : GCC 4.4.7 20120313 (Red Hat 4.4.7-1)
# system     : Linux
# release    : 3.16.7-7-desktop
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 4
# interpreter: 64bit
# Git hash   :

# %%
import iris
import pytz
from datetime import datetime, timedelta

from utilities import CF_names


# Hurricane Sandy Formed.
start = datetime(2012, 10, 22, 12)
# Dissipated.
stop = datetime(2012, 11, 2, 12)

stop = stop.replace(tzinfo=pytz.utc)
start = start.replace(tzinfo=pytz.utc)

# Region.
bbox = [-87, 24,
        -70, 42]

# CF-names to look for.
sos_name = 'water_surface_height_above_reference_datum'
name_list = CF_names[sos_name]

# Convert to units.
units = iris.unit.Unit('meters')

# %%
import os
import pyoos
import owslib

import logging as log
reload(log)

run_name = '{:%Y-%m-%d}'.format(stop)

if not os.path.exists(run_name):
    os.makedirs(run_name)
    msg = 'Saving data inside directory {}'.format(run_name)
else:
    msg = 'Overwriting the data inside directory {}'.format(run_name)

fmt = '{:*^64}'.format
log.captureWarnings(True)
LOG_FILENAME = 'log.txt'
LOG_FILENAME = os.path.join(run_name, LOG_FILENAME)
log.basicConfig(filename=LOG_FILENAME,
                filemode='w',
                format='%(asctime)s %(levelname)s: %(message)s',
                datefmt='%I:%M:%S',
                level=log.INFO,
                stream=None)

log.info(fmt(msg))
log.info(fmt(' Run information '))
log.info('Run date: {:%Y-%m-%d %H:%M:%S}'.format(datetime.utcnow()))
log.info('Download start: {:%Y-%m-%d %H:%M:%S}'.format(start))
log.info('Download stop: {:%Y-%m-%d %H:%M:%S}'.format(stop))
log.info('Bounding box: {0:3.2f}, {1:3.2f},'
         '{2:3.2f}, {3:3.2f}'.format(*bbox))
log.info(fmt(' Software version '))
log.info('Iris version: {}'.format(iris.__version__))
log.info('owslib version: {}'.format(owslib.__version__))
log.info('pyoos version: {}'.format(pyoos.__version__))

# %%
from owslib import fes
from utilities import fes_date_filter

kw = dict(wildCard='*',
          escapeChar='\\',
          singleChar='?',
          propertyname='apiso:AnyText')

or_filt = fes.Or([fes.PropertyIsLike(literal=('*%s*' % val), **kw)
                  for val in name_list])

# Exclude ROMS Averages and History files.
not_filt = fes.Not([fes.PropertyIsLike(literal='*Averages*', **kw)])

begin, end = fes_date_filter(start, stop)
filter_list = [fes.And([fes.BBox(bbox), begin, end, or_filt, not_filt])]

# %%
from owslib.csw import CatalogueServiceWeb

endpoint = 'http://www.ngdc.noaa.gov/geoportal/csw'
csw = CatalogueServiceWeb(endpoint, timeout=60)
csw.getrecords2(constraints=filter_list, maxrecords=1000, esn='full')

log.info(fmt(' Catalog information '))
log.info("URL: {}".format(endpoint))
log.info("CSW version: {}".format(csw.version))
log.info("Number of datasets available: {}".format(len(csw.records.keys())))

# %%
from utilities import service_urls

dap_urls = service_urls(csw.records, service='odp:url')
sos_urls = service_urls(csw.records, service='sos:url')

log.info(fmt(' CSW '))
for rec, item in csw.records.items():
    log.info('{}'.format(item.title))

log.info(fmt(' DAP '))
for url in dap_urls:
    log.info('{}.html'.format(url))

log.info(fmt(' SOS '))
for url in sos_urls:
    log.info('{}'.format(url))

# %%
from pyoos.collectors.coops.coops_sos import CoopsSos

collector = CoopsSos()

datum = 'NAVD'
collector.set_datum(datum)
collector.end_time = stop
collector.start_time = start
collector.variables = [sos_name]

ofrs = collector.server.offerings
title = collector.server.identification.title
log.info(fmt(' Collector offerings '))
log.info('{}: {} offerings'.format(title, len(ofrs)))

# %%
from pandas import read_csv
from utilities import sos_request

params = dict(observedProperty=sos_name,
              eventTime=start.strftime('%Y-%m-%dT%H:%M:%SZ'),
              featureOfInterest='BBOX:{0},{1},{2},{3}'.format(*bbox),
              offering='urn:ioos:network:NOAA.NOS.CO-OPS:WaterLevelActive')

uri = 'http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS'
url = sos_request(uri, **params)
observations = read_csv(url)

log.info('SOS URL request: {}'.format(url))

# %% [markdown]
# ### Clean the dataframe (visualization purpose only)

# %%
from utilities import get_coops_longname, to_html
columns = {'datum_id': 'datum',
           'sensor_id': 'sensor',
           'station_id': 'station',
           'latitude (degree)': 'lat',
           'longitude (degree)': 'lon',
           'vertical_position (m)': 'height',
           'water_surface_height_above_reference_datum (m)': sos_name}

observations.rename(columns=columns, inplace=True)
observations['datum'] = [s.split(':')[-1] for s in observations['datum']]
observations['sensor'] = [s.split(':')[-1] for s in observations['sensor']]
observations['station'] = [s.split(':')[-1] for s in observations['station']]
observations['name'] = [get_coops_longname(s) for s in observations['station']]

observations.set_index('name', inplace=True)
to_html(observations.head())
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>station</th>
#       <th>sensor</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>date_time</th>
#       <th>water_surface_height_above_reference_datum</th>
#       <th>datum</th>
#       <th>height</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Fall River, MA</th>
#       <td> 8447386</td>
#       <td> B1</td>
#       <td> 41.7043</td>
#       <td>-71.1641</td>
#       <td> 2012-10-22T12:00:00Z</td>
#       <td> 0.135</td>
#       <td> MLLW</td>
#       <td> 6.356</td>
#     </tr>
#     <tr>
#       <th>Woods Hole, MA</th>
#       <td> 8447930</td>
#       <td> B1</td>
#       <td> 41.5233</td>
#       <td>-70.6717</td>
#       <td> 2012-10-22T12:00:00Z</td>
#       <td> 0.155</td>
#       <td> MLLW</td>
#       <td> 0.797</td>
#     </tr>
#     <tr>
#       <th>Nantucket Island, MA</th>
#       <td> 8449130</td>
#       <td> A1</td>
#       <td> 41.2850</td>
#       <td>-70.0967</td>
#       <td> 2012-10-22T12:00:00Z</td>
#       <td> 0.937</td>
#       <td> MLLW</td>
#       <td> 0.915</td>
#     </tr>
#     <tr>
#       <th>Newport, RI</th>
#       <td> 8452660</td>
#       <td> B1</td>
#       <td> 41.5050</td>
#       <td>-71.3267</td>
#       <td> 2012-10-22T12:00:00Z</td>
#       <td> 0.288</td>
#       <td> MLLW</td>
#       <td> 0.577</td>
#     </tr>
#     <tr>
#       <th>Conimicut Light, RI</th>
#       <td> 8452944</td>
#       <td> B1</td>
#       <td> 41.7167</td>
#       <td>-71.3433</td>
#       <td> 2012-10-22T12:00:00Z</td>
#       <td>-0.159</td>
#       <td> MLLW</td>
#       <td> 5.650</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ### Generate a uniform 6-min time base for model/data comparison

# %%
from pandas import DataFrame
from owslib.ows import ExceptionReport
from utilities import coops2df, save_timeseries

iris.FUTURE.netcdf_promote = True

log.info(fmt(' Observations '))
fname = '{:%Y-%m-%d}-OBS_DATA.nc'.format(stop)
fname = os.path.join(run_name, fname)

log.info(fmt(' Downloading to file {} '.format(fname)))
data = dict()
bad_datum = []
for station in observations.station:
    try:
        df = coops2df(collector, station)
        col = 'water_surface_height_above_reference_datum (m)'
        data.update({station: df[col]})
    except ExceptionReport as e:
        bad_datum.append(station)
        name = get_coops_longname(station)
        log.warning("[{}] {}:\n{}".format(station, name, e))
obs_data = DataFrame.from_dict(data)

# Split good and bad vertical datum stations.
pattern = '|'.join(bad_datum)
if pattern:
    non_navd = observations.station.str.contains(pattern)
    bad_datum = observations[non_navd]
    observations = observations[~non_navd]

comment = "Several stations from http://opendap.co-ops.nos.noaa.gov"
kw = dict(longitude=observations.lon,
          latitude=observations.lat,
          station_attr=dict(cf_role="timeseries_id"),
          cube_attr=dict(featureType='timeSeries',
                         Conventions='CF-1.6',
                         standard_name_vocabulary='CF-1.6',
                         cdm_data_type="Station",
                         comment=comment,
                         datum=datum,
                         url=url))

save_timeseries(obs_data, outfile=fname,
                standard_name=sos_name, **kw)

to_html(obs_data.head())
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>8447930</th>
#       <th>8452660</th>
#       <th>8454000</th>
#       <th>8461490</th>
#       <th>8467150</th>
#       <th>8510560</th>
#       <th>8518750</th>
#       <th>8534720</th>
#       <th>8536110</th>
#       <th>8545240</th>
#       <th>8551910</th>
#       <th>8557380</th>
#       <th>8570283</th>
#       <th>8571421</th>
#       <th>8571892</th>
#       <th>8574680</th>
#       <th>8575512</th>
#       <th>8577330</th>
#       <th>8594900</th>
#       <th>8635750</th>
#       <th>8638610</th>
#       <th>8651370</th>
#       <th>8652587</th>
#       <th>8658163</th>
#       <th>8661070</th>
#       <th>8662245</th>
#       <th>8665530</th>
#       <th>8670870</th>
#       <th>8720030</th>
#       <th>8720218</th>
#       <th>8720357</th>
#       <th>8721604</th>
#       <th>8722670</th>
#       <th>8723214</th>
#       <th>8723970</th>
#       <th>8724580</th>
#       <th>8725110</th>
#       <th>8725520</th>
#       <th>8726384</th>
#       <th>8726667</th>
#       <th>8726724</th>
#       <th>8727520</th>
#       <th>8728690</th>
#       <th>8729108</th>
#     </tr>
#     <tr>
#       <th>date_time</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2012-10-22 12:00:00</th>
#       <td>-0.250</td>
#       <td>-0.334</td>
#       <td>-0.628</td>
#       <td>-0.289</td>
#       <td> 0.165</td>
#       <td>-0.256</td>
#       <td>-0.707</td>
#       <td>-0.680</td>
#       <td>-0.733</td>
#       <td> 0.835</td>
#       <td> 0.078</td>
#       <td> 0.068</td>
#       <td>-0.426</td>
#       <td> 0.192</td>
#       <td> 0.043</td>
#       <td>-0.147</td>
#       <td>-0.030</td>
#       <td> 0.171</td>
#       <td>-0.310</td>
#       <td> 0.201</td>
#       <td>-0.259</td>
#       <td>-0.524</td>
#       <td>-0.025</td>
#       <td>-0.630</td>
#       <td>-0.773</td>
#       <td>-0.614</td>
#       <td>-0.768</td>
#       <td>-0.873</td>
#       <td>-0.721</td>
#       <td>-0.583</td>
#       <td> 0.181</td>
#       <td>-0.675</td>
#       <td>-0.624</td>
#       <td>-0.385</td>
#       <td>-0.029</td>
#       <td>-0.229</td>
#       <td> 0.123</td>
#       <td> 0.029</td>
#       <td> 0.133</td>
#       <td> 0.192</td>
#       <td> 0.134</td>
#       <td> 0.399</td>
#       <td> 0.314</td>
#       <td> 0.242</td>
#     </tr>
#     <tr>
#       <th>2012-10-22 12:06:00</th>
#       <td>-0.248</td>
#       <td>-0.325</td>
#       <td>-0.628</td>
#       <td>-0.309</td>
#       <td> 0.120</td>
#       <td>-0.273</td>
#       <td>-0.722</td>
#       <td>-0.693</td>
#       <td>-0.732</td>
#       <td> 0.846</td>
#       <td> 0.038</td>
#       <td> 0.059</td>
#       <td>-0.411</td>
#       <td> 0.190</td>
#       <td> 0.055</td>
#       <td>-0.150</td>
#       <td>-0.026</td>
#       <td> 0.171</td>
#       <td>-0.321</td>
#       <td> 0.199</td>
#       <td>-0.271</td>
#       <td>-0.528</td>
#       <td>-0.028</td>
#       <td>-0.631</td>
#       <td>-0.764</td>
#       <td>-0.629</td>
#       <td>-0.774</td>
#       <td>-0.892</td>
#       <td>-0.747</td>
#       <td>-0.597</td>
#       <td> 0.171</td>
#       <td>-0.695</td>
#       <td>-0.625</td>
#       <td>-0.394</td>
#       <td>-0.032</td>
#       <td>-0.233</td>
#       <td> 0.106</td>
#       <td> 0.035</td>
#       <td> 0.127</td>
#       <td> 0.194</td>
#       <td> 0.123</td>
#       <td> 0.393</td>
#       <td> 0.314</td>
#       <td> 0.236</td>
#     </tr>
#     <tr>
#       <th>2012-10-22 12:12:00</th>
#       <td>-0.261</td>
#       <td>-0.348</td>
#       <td>-0.627</td>
#       <td>-0.325</td>
#       <td> 0.076</td>
#       <td>-0.284</td>
#       <td>-0.734</td>
#       <td>-0.675</td>
#       <td>-0.760</td>
#       <td> 0.850</td>
#       <td> 0.010</td>
#       <td> 0.048</td>
#       <td>-0.409</td>
#       <td> 0.189</td>
#       <td> 0.068</td>
#       <td>-0.154</td>
#       <td>-0.022</td>
#       <td> 0.172</td>
#       <td>-0.331</td>
#       <td> 0.197</td>
#       <td>-0.279</td>
#       <td>-0.516</td>
#       <td>-0.029</td>
#       <td>-0.634</td>
#       <td>-0.753</td>
#       <td>-0.643</td>
#       <td>-0.782</td>
#       <td>-0.914</td>
#       <td>-0.774</td>
#       <td>-0.610</td>
#       <td> 0.161</td>
#       <td>-0.659</td>
#       <td>-0.635</td>
#       <td>-0.404</td>
#       <td>-0.034</td>
#       <td>-0.234</td>
#       <td> 0.102</td>
#       <td> 0.040</td>
#       <td> 0.123</td>
#       <td> 0.

# %% [markdown]
# ### Loop discovered models and save the nearest time-series

# %%
import warnings

from iris.exceptions import (CoordinateNotFoundError, ConstraintMismatchError,
                             MergeError)
from utilities import (TimeoutException, quick_load_cubes, proc_cube, time_limit,
                       get_model_name, is_model, get_surface)

log.info(fmt(' Models '))
cubes = dict()

with warnings.catch_warnings():
    warnings.simplefilter("ignore")  # Suppress iris warnings.
    for k, url in enumerate(dap_urls):
        log.info('\n[Reading url {}/{}]: {}'.format(k+1, len(dap_urls), url))
        try:
            with time_limit(60*5):
                cube = quick_load_cubes(url, name_list, callback=None, strict=True)
                if is_model(cube):
                    cube = proc_cube(cube, bbox=bbox, time=(start, stop), units=units)
                else:
                    log.warning("[Not model data]: {}".format(url))
                    continue
                # FIXME: Surface data only!
                cube = get_surface(cube)
                mod_name, model_full_name = get_model_name(cube, url)
                cubes.update({mod_name: cube})
        except (TimeoutException, RuntimeError, ValueError,
                ConstraintMismatchError, CoordinateNotFoundError,
                IndexError) as e:
            log.warning('Cannot get cube for: {}\n{}'.format(url, e))

# %%
from iris.pandas import as_series

from utilities import (make_tree, get_nearest_water,
                       add_station, ensure_timeseries)

for mod_name, cube in cubes.items():
    fname = '{:%Y-%m-%d}-{}.nc'.format(stop, mod_name)
    fname = os.path.join(run_name, fname)
    log.info(fmt(' Saving to file {} '.format(fname)))
    try:
        tree, lon, lat = make_tree(cube)
    except CoordinateNotFoundError as e:
        log.warning('Cannot create KDTree for: {}'.format(mod_name))
        continue
    # Get model series at observed locations.
    raw_series = dict()
    for station, obs in observations.iterrows():
        try:
            kw = dict(k=10, max_dist=0.04, min_var=0.01)
            args = cube, tree, obs.lon, obs.lat
            series, dist, idx = get_nearest_water(*args, **kw)
        except ValueError as e:
            status = "No Data"
            log.info('[{}] {}'.format(status, obs.name))
            continue
        if not series:
            status = "Land   "
        else:
            raw_series.update({obs['station']: series})
            series = as_series(series)
            status = "Water  "

        log.info('[{}] {}'.format(status, obs.name))


    if raw_series:  # Save cube.
        for station, cube in raw_series.items():
            cube = add_station(cube, station)
        try:
            cube = iris.cube.CubeList(raw_series.values()).merge_cube()
        except MergeError as e:
            log.warning(e)

        ensure_timeseries(cube)
        iris.save(cube, fname)
        del cube

    log.info('Finished processing [{}]: {}'.format(mod_name, url))

# %% [markdown]
# ### Bias

# %%
import numpy as np
from glob import glob
from pandas import Panel
from utilities import nc2df


def load_secoora_ncs(run_name):
    fname = '{}-{}.nc'.format
    OBS_DATA = nc2df(os.path.join(run_name,
                                  fname(run_name, 'OBS_DATA')))
    index = OBS_DATA.index
    dfs = dict(OBS_DATA=OBS_DATA)
    for fname in glob(os.path.join(run_name, "*.nc")):
        if 'OBS_DATA' in fname:
            continue
        else:
            model = fname.split('.')[0].split('-')[-1]
            df = nc2df(fname)
            # FIXME: Horrible work around duplicate times.
            if len(df.index.values) != len(np.unique(df.index.values)):
                kw = dict(cols='index', take_last=True)
                df = df.reset_index().drop_duplicates(**kw).set_index('index')
            kw = dict(method='time', limit=30)
            df = df.reindex(index).interpolate(**kw).ix[index]
            dfs.update({model: df})

    return Panel.fromDict(dfs).swapaxes(0, 2)

dfs = load_secoora_ncs(run_name)

# %%
from pandas import DataFrame

means = dict()
for station, df in dfs.iteritems():
    mean = df.mean()
    try:
        mean_data = mean['OBS_DATA']
        means.update({station: mean.drop('OBS_DATA') - mean_data})
    except KeyError:
        mean_data = np.NaN
        means.update({station: mean - mean_data})

bias = DataFrame.from_dict(means)
bias = bias.applymap('{:.2f}'.format).replace('nan', '--')

columns = dict()
for station in bias.columns:
    sta_name = observations['station'][observations['station'] == station].index[0]
    columns.update({station: sta_name})
bias.rename(columns=columns, inplace=True)

# %%
fname = os.path.join(run_name, 'bias.html'.format(run_name))

html_bias = to_html(bias.T)

with open(fname, 'w') as f:
    f.writelines(html_bias.data)

to_html(bias.T)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>COAWST_4</th>
#       <th>USF_ROMS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Woods Hole, MA</th>
#       <td> -0.07</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Newport, RI</th>
#       <td> -0.30</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Providence, RI</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>New London, CT</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Bridgeport, CT</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Montauk, NY</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>The Battery, NY</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Atlantic City, NJ</th>
#       <td> -0.01</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Cape May, NJ</th>
#       <td> -0.06</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Philadelphia, PA</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Reedy Point, DE</th>
#       <td> -0.04</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Lewes, DE</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Ocean City Inlet, MD</th>
#       <td> -0.08</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Bishops Head, MD</th>
#       <td> -0.10</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Cambridge, MD</th>
#       <td> -0.17</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Baltimore, MD</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Annapolis, MD</th>
#       <td> -0.19</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Solomons Island, MD</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Washington, DC</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Lewisetta, VA</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Sewells Point, VA</th>
#       <td> -0.09</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Duck, NC</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td> -0.08</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Wrightsville Beach, NC</th>
#       <td> -0.01</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Springmaid Pier, SC</th>
#       <td> -0.02</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Oyster Landing (N Inlet Estuary), SC</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Charleston, SC</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Fort Pulaski, GA</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Fernandina Beach, FL</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Mayport (Bar Pilots Dock), FL</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>I-295 Bridge, St Johns River, FL</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Trident Pier, FL</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Lake Worth Pier, FL</th>
#       <td>  0.21</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Virginia Key, FL</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Vaca Key, FL</th>
#       <td>    --</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Key West, FL</th>
#       <td>  0.29</td>
#       <td>    --</td>
#     </tr>
#     <tr>
#       <th>Naples, FL</th>
#       <td>    --</td>
#       <td> -0.02</td>
#     </tr>
#     <tr>
#       <th>Fort Myers, FL</th>
#       <td>    --</td>
#       <td> -0.16</td>
#     </tr>
#     <tr>
#       <th>Port Manatee, FL</th>
#       <td>    --</td>
#       <td> -0.14</td>
#     </tr>
#     <tr>
#       <th>Mckay Bay Entrance, FL</th>
#       <td>    --</td>
#       <td> -0.05</td>
#     </tr>
#     <tr>
#       <th>Clearwater Beach, FL</th>
#       <td>    --</td>
#       <td> -0.08</td>
#     </tr>
#     <tr>
#       <th>Cedar Key, FL</th>
#       <td>  0.03</td>
#       <td> -0.05</td>
#     </tr>
#     <tr>
#       <th>Apalachicola, FL</th>
#       <td> -0.05</td>
#       <td> -0.12</td>
#     </tr>
#     <tr>
#       <th>Panama City, FL</th>
#       <td> -0.07</td>
#       <td> -0.27</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ### Model skill

# %%
from utilities import pearsonr_paired

dfs = load_secoora_ncs(run_name)

skills = dict()
for station, df in dfs.iteritems():
    skill = dict()
    try:
        obs = df.pop('OBS_DATA')
        for model, y in df.iteritems():
            r, p = pearsonr_paired(obs, y)
            if p > 0.01:
                r = np.NaN
            skill.update({model: r})
    except KeyError:  # All NaN data.
        for model, y in df.iteritems():
            skill.update({model: np.NaN})
            print(model)
    skills.update({station: skill})

df = DataFrame.from_dict(skills)

columns = dict()
for station in df.columns:
    sta_name = observations['station'][observations['station'] == station].index[0]
    columns.update({station: sta_name})

df.rename(columns=columns, inplace=True)

# %%
fname = os.path.join(run_name, 'skill.html'.format(run_name))

df_skill = df.applymap('{:.2f}'.format).replace('nan', '--')

html_skill = to_html(df_skill.T)

with open(fname, 'w') as f:
    f.writelines(html_skill.data)

to_html(df_skill.T)
# Out:
# <style>.info {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .success {
#     background-color:#d9edf7;
#     border-color:#bce8f1;
#     border-left:5px solid #31708f;
#     padding:.5em;
#     color:#31708f
# }
#
# .error {
#     background-color:#f2dede;
#     border-color:#ebccd1;
#     border-left:5px solid #a94442;
#     padding:.5em;
#     color:#a94442
# }
#
# .warning {
#     background-color:#fcf8e3;
#     border-color:#faebcc;
#     border-left:5px solid #8a6d3b;
#     padding:.5em;
#     color:#8a6d3b
# }
#
# .text-shadow {
#     text-shadow:0 1px 0 #ccc,0 2px 0 #c9c9c9,0 3px 0 #bbb,0 4px 0 #b9b9b9,0 5px 0 #aaa,0 6px 1px rgba(0,0,0,.1)
# }
#
# .datagrid table {
#     border-collapse:collapse;
#     text-align:left;
#     width:65%
# }
#
# .datagrid td {
#     border-collapse:collapse;
#     text-align:right;
# }
#
# .datagrid {
#     font:normal 12px/150% Arial,Helvetica,sans-serif;
#     background:#fff;
#     overflow:hidden;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px
# }
#
# .datagrid table td,.datagrid table th {
#     padding:3px 10px
# }
#
# .datagrid table thead th {
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069;
#     color:#FFF;
#     font-size:15px;
#     font-weight:700;
#     border-left:1px solid #0070A8
# }
#
# .datagrid table thead th:first-child {
#     border:none
# }
#
# .datagrid table tbody td {
#     color:#00496B;
#     border-left:1px solid #E1EEF4;
#     font-size:12px;
#     font-weight:400
# }
#
# .datagrid table tbody .alt td {
#     background:#E1EEF4;
#     color:#00496B
# }
#
# .datagrid table tbody td:first-child {
#     border-left:none
# }
#
# .datagrid table tbody tr:last-child td {
#     border-bottom:none
# }
#
# .datagrid table tfoot td div {
#     border-top:1px solid #069;
#     background:#E1EEF4
# }
#
# .datagrid table tfoot td {
#     padding:0;
#     font-size:12px
# }
#
# .datagrid table tfoot td div {
#     padding:2px
# }
#
# .datagrid table tfoot td ul {
#     margin:0;
#     padding:0;
#     list-style:none;
#     text-align:right
# }
#
# .datagrid table tfoot li {
#     display:inline
# }
#
# .datagrid table tfoot li a {
#     text-decoration:none;
#     display:inline-block;
#     padding:2px 8px;
#     margin:1px;
#     color:#FFF;
#     border:1px solid #069;
#     -webkit-border-radius:3px;
#     -moz-border-radius:3px;
#     border-radius:3px;
#     background:-webkit-gradient(linear,left top,left bottom,color-stop(0.05,#069),color-stop(1,#00557F));
#     background:-moz-linear-gradient(center top,#069 5%,#00557F 100%);
#     filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#006699',endColorstr='#00557F');
#     background-color:#069
# }
#
# .datagrid table tfoot ul.active,.datagrid table tfoot ul a:hover {
#     text-decoration:none;
#     border-color:#069;
#     color:#FFF;
#     background:none;
#     background-color:#00557F
# }
#
# div.dhtmlx_window_active,div.dhx_modal_cover_dv {
#     position:fixed!important
# }
# </style><div class="datagrid"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>COAWST_4</th>
#       <th>USF_ROMS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Woods Hole, MA</th>
#       <td> 0.89</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Newport, RI</th>
#       <td> 0.86</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Providence, RI</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>New London, CT</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Bridgeport, CT</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Montauk, NY</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>The Battery, NY</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Atlantic City, NJ</th>
#       <td> 0.93</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Cape May, NJ</th>
#       <td> 0.96</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Philadelphia, PA</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Reedy Point, DE</th>
#       <td> 0.78</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Lewes, DE</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Ocean City Inlet, MD</th>
#       <td> 0.96</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Bishops Head, MD</th>
#       <td> 0.95</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Cambridge, MD</th>
#       <td> 0.89</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Baltimore, MD</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Annapolis, MD</th>
#       <td> 0.89</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Solomons Island, MD</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Washington, DC</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Lewisetta, VA</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Sewells Point, VA</th>
#       <td> 0.96</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Duck, NC</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Oregon Inlet Marina, NC</th>
#       <td> 0.55</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Wrightsville Beach, NC</th>
#       <td> 0.95</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Springmaid Pier, SC</th>
#       <td> 0.95</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Oyster Landing (N Inlet Estuary), SC</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Charleston, SC</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Fort Pulaski, GA</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Fernandina Beach, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Mayport (Bar Pilots Dock), FL</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>I-295 Bridge, St Johns River, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Trident Pier, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Lake Worth Pier, FL</th>
#       <td> 0.93</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Virginia Key, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Vaca Key, FL</th>
#       <td>   --</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Key West, FL</th>
#       <td> 0.96</td>
#       <td>   --</td>
#     </tr>
#     <tr>
#       <th>Naples, FL</th>
#       <td>   --</td>
#       <td> 0.46</td>
#     </tr>
#     <tr>
#       <th>Fort Myers, FL</th>
#       <td>   --</td>
#       <td> 0.83</td>
#     </tr>
#     <tr>
#       <th>Port Manatee, FL</th>
#       <td>   --</td>
#       <td> 0.74</td>
#     </tr>
#     <tr>
#       <th>Mckay Bay Entrance, FL</th>
#       <td>   --</td>
#       <td> 0.39</td>
#     </tr>
#     <tr>
#       <th>Clearwater Beach, FL</th>
#       <td>   --</td>
#       <td> 0.49</td>
#     </tr>
#     <tr>
#       <th>Cedar Key, FL</th>
#       <td> 0.86</td>
#       <td> 0.18</td>
#     </tr>
#     <tr>
#       <th>Apalachicola, FL</th>
#       <td> 0.92</td>
#       <td> 0.73</td>
#     </tr>
#     <tr>
#       <th>Panama City, FL</th>
#       <td> 0.92</td>
#       <td> 0.82</td>
#     </tr>
#   </tbody>
# </table></div>

# %% [markdown]
# ### Map

# %%
from mpld3 import save_html
import matplotlib.pyplot as plt
from mpld3.plugins import LineLabelTooltip, connect

from utilities import make_map

mapa = make_map(bbox, line=True, states=False)

# %% [markdown]
# #### ROMS stations files (SABGOM and USEAST)

# %%
roms_stations = [(-77.7866, 34.2133),
                 (-78.9183, 33.6550),
                 (-81.0000, 30.3966),
                 (-80.1600, 25.7300),
                 (-81.8116, 24.5550),
                 (-82.6137, 26.1300),
                 (-82.8320, 27.9770),
                 (-86.4987, 30.1520)]

for station in roms_stations:
    location = station[::-1]
    popup = '[SABGOM/USEAST]\nROMS station file'
    kw = dict(radius=700, fill_color='red', popup=popup,
              fill_opacity=0.75)
    mapa.circle_marker(location=location, **kw)

# %% [markdown]
# #### Clusters

# %%
from glob import glob
from operator import itemgetter


big_list = []
for fname in glob(os.path.join(run_name, "*.nc")):
    if 'OBS_DATA' in fname:
        continue
    cube = iris.load_cube(fname)
    model = fname.split('-')[-1].split('.')[0]
    lons = cube.coord(axis='X').points
    lats = cube.coord(axis='Y').points
    stations = cube.coord('station name').points
    models = [model]*lons.size
    lista = zip(models, lons.tolist(), lats.tolist(), stations.tolist())
    big_list.extend(lista)

big_list.sort(key=itemgetter(3))
df = DataFrame(big_list, columns=['name', 'lon', 'lat', 'station'])
df.set_index('station', drop=True, inplace=True)
groups = df.groupby(df.index)


for station, info in groups:
    sta_name = observations['station'][observations['station'] == station].index[0]
    for lat, lon, name in zip(info.lat, info.lon, info.name):
        location = lat, lon
        popup = '<b>{}</b>\n{}'.format(sta_name, name)
        mapa.simple_marker(location=location, popup=popup,
                           clustered_marker=True)

# %% [markdown]
# #### Model and observations plots

# %%
resolution, width, height = 75, 7, 3


def make_plot():
    fig, ax = plt.subplots(figsize=(width, height))
    ax.set_ylabel('Sea surface height ({})'.format(units))
    ax.set_ylim(-2.5, 2.5)
    ax.grid(True)
    return fig, ax

dfs = load_secoora_ncs(run_name)

for station in dfs:
    sta_name = observations['station'][observations['station'] == station].index[0]
    df = dfs[station].dropna(axis=1, how='all')
    if df.empty:
        continue

    fig, ax = make_plot()
    labels = []
    for col in df.columns:
        lines = ax.plot(df.index, df[col], linewidth=2.5, alpha=0.5,
                        label=col)
        if 'OBS_DATA' not in col:
            text0 = col
            text1 = bias[sta_name][col]
            text2 = df_skill[sta_name][col]
            tooltip = '{}:\nbias {}\nskill: {}'.format
            labels.append(tooltip(text0, text1, text2))
        else:
            labels.append('OBS_DATA')
    kw = dict(loc='upper center', bbox_to_anchor=(0.5, 1.05), numpoints=1,
              ncol=2, framealpha=0)
    l = ax.legend(**kw)
    l.set_title("")  # Workaround str(None).
    
    [connect(fig, LineLabelTooltip(line, name))
     for line, name in zip(ax.lines, labels)]

    html = 'station_{}.html'.format(station)
    save_html(fig, '{}/{}'.format(run_name, html))
    plt.close(fig)

    popup = "<div align='center'> {} <br><iframe src='{}' alt='image'"
    popup += "width='{}px' height='{}px' frameBorder='0'></div>"
    popup = popup.format('{}'.format(sta_name), html,
                         (width*resolution)+75, (height*resolution)+50)
    kw = dict(popup=popup, width=(width*resolution)+75)

    if (df.columns == 'OBS_DATA').all():
        kw.update(dict(marker_color="blue", marker_icon="ok"))
    else:
        conj = set(df.columns)
        if conj:
            kw.update(dict(marker_color="green", marker_icon="ok-sign"))
        else:
            kw.update(dict(marker_color="green", marker_icon="ok"))
    obs = observations[observations['station'] == station].squeeze()
    mapa.simple_marker(location=[obs['lat'], obs['lon']], **kw)

# %% [markdown]
# #### Bad stations

# %%
if isinstance(bad_datum, DataFrame):
    for station, obs in bad_datum.iterrows():
        popup = '<b>Station:</b> {}<br><b>Datum:</b> {}<br>'
        popup = popup.format(station, obs['datum'])
        kw = dict(popup=popup, marker_color="red", marker_icon="question-sign")
        mapa.simple_marker(location=[obs['lat'], obs['lon']], **kw)

# %%
from utilities import inline_map


mapa.create_map(path=os.path.join(run_name, 'mapa.html'))
inline_map(os.path.join(run_name, 'mapa.html'))
# Out:
#         <iframe
#             width="750"
#             height=500"
#             src="2012-11-02/mapa.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
elapsed = time.time() - start_time
log.info('{:.2f} minutes'.format(elapsed/60.))
log.info('EOF')

with open('{}/log.txt'.format(run_name)) as f:
    print(f.read())
# Out:
# 06:33:28 INFO: ************Saving data inside directory 2012-11-02*************
# 06:33:28 INFO: *********************** Run information ************************
# 06:33:28 INFO: Run date: 2015-03-31 21:33:28
# 06:33:28 INFO: Download start: 2012-10-22 12:00:00
# 06:33:28 INFO: Download stop: 2012-11-02 12:00:00
# 06:33:28 INFO: Bounding box: -87.00, 24.00,-70.00, 42.00
# 06:33:28 INFO: *********************** Software version ***********************
# 06:33:28 INFO: Iris version: 1.8.0-DEV
# 06:33:28 INFO: owslib version: 0.8.13
# 06:33:28 INFO: pyoos version: 0.6.2
# 06:33:32 INFO: ********************* Catalog information **********************
# 06:33:32 INFO: URL: http://www.ngdc.noaa.gov/geoportal/csw
# 06:33:32 INFO: CSW version: 2.0.2
# 06:33:32 INFO: Number of datasets available: 5
# 06:33:32 INFO: ***************************** CSW ******************************
# 06:33:32 INFO: COAWST Forecast System : USGS : US East Coast and Gulf of Mexico (Experimental)
# 06:33:32 INFO: ROMS/TOMS 3.0 - New Floria Shelf Application
# 06:33:32 INFO: Barotropic Tide Model for the Pacific Basin
# 06:33:32 INFO: NOAA.NOS.CO-OPS SOS
# 06:33:32 INFO: HYbrid Coordinate Ocean Model (HYCOM): Global
# 06:33:32 INFO: ***************************** DAP ******************************
# 06:33:32 INFO: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd.html
# 06:33:32 INFO: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd.html
# 06:33:32 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac.html
# 06:33:32 INFO: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global.html
# 06:33:32 INFO: ***************************** SOS ******************************
# 06:33:32 INFO: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?service=SOS&request=GetCapabilities
# 06:33:38 INFO: ********************* Collector offerings **********************
# 06:33:38 INFO: NOAA.NOS.CO-OPS SOS: 1040 offerings
# 06:33:48 INFO: SOS URL request: http://opendap.co-ops.nos.noaa.gov/ioos-dif-sos/SOS?eventTime=2012-10-22T12%3A00%3A00Z&service=SOS&offering=urn%3Aioos%3Anetwork%3ANOAA.NOS.CO-OPS%3AWaterLevelActive&request=GetObservation&version=1.0.0&responseFormat=text%2Fcsv&featureOfInterest=BBOX%3A-87%2C24%2C-70%2C42&observedProperty=water_surface_height_above_reference_datum
# 06:34:18 INFO: ************************* Observations *************************
# 06:34:18 INFO: **** Downloading to file 2012-11-02/2012-11-02-OBS_DATA.nc *****
# 06:34:20 WARNING: [8447386] Fall River, MA:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:34:24 WARNING: [8449130] Nantucket Island, MA:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:34:28 WARNING: [8452944] Conimicut Light, RI:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:34:33 WARNING: [8454049] Quonset Point, RI:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:34:39 WARNING: [8465705] New Haven, CT:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:34:51 WARNING: [8516945] Kings Point, NY:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:02 WARNING: [8537121] Ship John Shoal, NJ:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:04 WARNING: [8539094] Burlington, Delaware River, NJ:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:05 WARNING: [8540433] Marcus Hook, PA:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:10 WARNING: [8548989] Newbold, PA:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:11 WARNING: [8551762] Delaware City, DE:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:27 WARNING: [8573364] Tolchester Beach, MD:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:28 WARNING: [8573927] Chesapeake City, MD:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:42 WARNING: [8636580] Windmill Point, VA:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:43 WARNING: [8637689] Yorktown USCG Training Center, VA:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:47 WARNING: [8638863] Chesapeake Bay Bridge Tunnel, VA:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:48 WARNING: [8639348] Money Point, VA:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:54 WARNING: [8654467] USCG Station Hatteras, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:55 WARNING: [8656483] Beaufort, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:35:56 WARNING: [8658120] Wilmington, NC:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:36:42 WARNING: [8726520] St Petersburg, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:36:45 WARNING: [8726607] Old Port Tampa, FL:
# 'Wrong Datum for this station: The correct Datum values are: MHHW, MHW, MTL, MSL, MLW, MLLW, STND'
# 06:37:00 WARNING: [9063053] Fairport, OH:
# 'Wrong Datum for this station: The correct Datum value is: IGLD'
# 06:37:02 WARNING: [9063063] Cleveland, OH:
# 'Wrong Datum for this station: The correct Datum value is: IGLD'
# 06:37:02 WARNING: [9063079] Marblehead, OH:
# 'Wrong Datum for this station: The correct Datum value is: IGLD'
# 06:37:03 WARNING: [9063085] Toledo, OH:
# 'Wrong Datum for this station: The correct Datum value is: IGLD'
# 06:37:04 WARNING: [9063090] Fermi Power Plant, MI:
# 'Wrong Datum for this station: The correct Datum value is: IGLD'
# 06:37:04 INFO: **************************** Models ****************************
# 06:37:04 INFO:
# [Reading url 1/4]: http://crow.marine.usf.edu:8080/thredds/dodsC/WFS_ROMS_NF_model/USF_Ocean_Circulation_Group_West_Florida_Shelf_Daily_ROMS_Nowcast_Forecast_Model_Data_best.ncd
# 06:37:10 INFO:
# [Reading url 2/4]: http://geoport.whoi.edu/thredds/dodsC/coawst_4/use/fmrc/coawst_4_use_best.ncd
# 06:37:37 INFO:
# [Reading url 3/4]: http://oos.soest.hawaii.edu/thredds/dodsC/hioos/tide_pac
# 06:37:40 INFO:
# [Reading url 4/4]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# 06:37:42 WARNING: Cannot get cube for: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# istart must be different from istop! Got istart 0 and  istop 0
# 06:37:43 INFO: ******* Saving to file 2012-11-02/2012-11-02-USF_ROMS.nc *******
# 06:37:43 INFO: [No Data] Woods Hole, MA
# 06:37:43 INFO: [No Data] Newport, RI
# 06:37:43 INFO: [No Data] Providence, RI
# 06:37:43 INFO: [No Data] New London, CT
# 06:37:43 INFO: [No Data] Bridgeport, CT
# 06:37:43 INFO: [No Data] Montauk, NY
# 06:37:43 INFO: [No Data] The Battery, NY
# 06:37:43 INFO: [No Data] Atlantic City, NJ
# 06:37:43 INFO: [No Data] Cape May, NJ
# 06:37:43 INFO: [No Data] Philadelphia, PA
# 06:37:43 INFO: [No Data] Reedy Point, DE
# 06:37:43 INFO: [No Data] Lewes, DE
# 06:37:43 INFO: [No Data] Ocean City Inlet, MD
# 06:37:43 INFO: [No Data] Bishops Head, MD
# 06:37:43 INFO: [No Data] Cambridge, MD
# 06:37:43 INFO: [No Data] Baltimore, MD
# 06:37:43 INFO: [No Data] Annapolis, MD
# 06:37:43 INFO: [No Data] Solomons Island, MD
# 06:37:43 INFO: [No Data] Washington, DC
# 06:37:43 INFO: [No Data] Lewisetta, VA
# 06:37:43 INFO: [No Data] Sewells Point, VA
# 06:37:43 INFO: [No Data] Duck, NC
# 06:37:43 INFO: [No Data] Oregon Inlet Marina, NC
# 06:37:43 INFO: [No Data] Wrightsville Beach, NC
# 06:37:43 INFO: [No Data] Springmaid Pier, SC
# 06:37:43 INFO: [No Data] Oyster Landing (N Inlet Estuary), SC
# 06:37:43 INFO: [No Data] Charleston, SC
# 06:37:43 INFO: [No Data] Fort Pulaski, GA
# 06:37:43 INFO: [No Data] Fernandina Beach, FL
# 06:37:43 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 06:37:43 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 06:37:43 INFO: [No Data] Trident Pier, FL
# 06:37:43 INFO: [No Data] Lake Worth Pier, FL
# 06:37:43 INFO: [No Data] Virginia Key, FL
# 06:37:43 INFO: [No Data] Vaca Key, FL
# 06:37:43 INFO: [No Data] Key West, FL
# 06:37:44 INFO: [Water  ] Naples, FL
# 06:37:45 INFO: [Water  ] Fort Myers, FL
# 06:37:48 INFO: [Water  ] Port Manatee, FL
# 06:37:49 INFO: [Water  ] Mckay Bay Entrance, FL
# 06:37:51 INFO: [Water  ] Clearwater Beach, FL
# 06:37:55 INFO: [Water  ] Cedar Key, FL
# 06:37:57 INFO: [Water  ] Apalachicola, FL
# 06:38:00 INFO: [Water  ] Panama City, FL
# 06:38:10 INFO: Finished processing [USF_ROMS]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# 06:38:10 INFO: ******* Saving to file 2012-11-02/2012-11-02-COAWST_4.nc *******
# 06:38:18 INFO: [Water  ] Woods Hole, MA
# 06:38:36 INFO: [Water  ] Newport, RI
# 06:38:43 INFO: [Land   ] Providence, RI
# 06:38:50 INFO: [Land   ] New London, CT
# 06:39:00 INFO: [Land   ] Bridgeport, CT
# 06:39:15 INFO: [Land   ] Montauk, NY
# 06:39:20 INFO: [Land   ] The Battery, NY
# 06:39:28 INFO: [Water  ] Atlantic City, NJ
# 06:39:42 INFO: [Water  ] Cape May, NJ
# 06:39:48 INFO: [Land   ] Philadelphia, PA
# 06:39:55 INFO: [Water  ] Reedy Point, DE
# 06:40:03 INFO: [Land   ] Lewes, DE
# 06:40:21 INFO: [Water  ] Ocean City Inlet, MD
# 06:40:36 INFO: [Water  ] Bishops Head, MD
# 06:40:42 INFO: [Water  ] Cambridge, MD
# 06:40:50 INFO: [Land   ] Baltimore, MD
# 06:40:55 INFO: [Water  ] Annapolis, MD
# 06:41:02 INFO: [Land   ] Solomons Island, MD
# 06:41:08 INFO: [Land   ] Washington, DC
# 06:41:15 INFO: [Land   ] Lewisetta, VA
# 06:41:28 INFO: [Water  ] Sewells Point, VA
# 06:41:34 INFO: [Land   ] Duck, NC
# 06:41:45 INFO: [Water  ] Oregon Inlet Marina, NC
# 06:41:54 INFO: [Water  ] Wrightsville Beach, NC
# 06:42:08 INFO: [Water  ] Springmaid Pier, SC
# 06:42:14 INFO: [Land   ] Oyster Landing (N Inlet Estuary), SC
# 06:42:21 INFO: [Land   ] Charleston, SC
# 06:42:30 INFO: [Land   ] Fort Pulaski, GA
# 06:42:38 INFO: [Land   ] Fernandina Beach, FL
# 06:42:44 INFO: [Land   ] Mayport (Bar Pilots Dock), FL
# 06:42:50 INFO: [Land   ] I-295 Bridge, St Johns River, FL
# 06:42:57 INFO: [Land   ] Trident Pier, FL
# 06:43:13 INFO: [Water  ] Lake Worth Pier, FL
# 06:43:19 INFO: [Land   ] Virginia Key, FL
# 06:43:27 INFO: [Land   ] Vaca Key, FL
# 06:43:42 INFO: [Water  ] Key West, FL
# 06:43:48 INFO: [Land   ] Naples, FL
# 06:43:54 INFO: [Land   ] Fort Myers, FL
# 06:44:01 INFO: [Land   ] Port Manatee, FL
# 06:44:10 INFO: [Land   ] Mckay Bay Entrance, FL
# 06:44:18 INFO: [Land   ] Clearwater Beach, FL
# 06:44:31 INFO: [Water  ] Cedar Key, FL
# 06:44:37 INFO: [Water  ] Apalachicola, FL
# 06:44:45 INFO: [Water  ] Panama City, FL
# 06:46:53 INFO: Finished processing [COAWST_4]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# 06:46:53 INFO: ******** Saving to file 2012-11-02/2012-11-02-BTMPB.nc *********
# 06:46:53 INFO: [No Data] Woods Hole, MA
# 06:46:53 INFO: [No Data] Newport, RI
# 06:46:53 INFO: [No Data] Providence, RI
# 06:46:53 INFO: [No Data] New London, CT
# 06:46:53 INFO: [No Data] Bridgeport, CT
# 06:46:53 INFO: [No Data] Montauk, NY
# 06:46:53 INFO: [No Data] The Battery, NY
# 06:46:53 INFO: [No Data] Atlantic City, NJ
# 06:46:53 INFO: [No Data] Cape May, NJ
# 06:46:53 INFO: [No Data] Philadelphia, PA
# 06:46:53 INFO: [No Data] Reedy Point, DE
# 06:46:53 INFO: [No Data] Lewes, DE
# 06:46:53 INFO: [No Data] Ocean City Inlet, MD
# 06:46:53 INFO: [No Data] Bishops Head, MD
# 06:46:53 INFO: [No Data] Cambridge, MD
# 06:46:53 INFO: [No Data] Baltimore, MD
# 06:46:53 INFO: [No Data] Annapolis, MD
# 06:46:53 INFO: [No Data] Solomons Island, MD
# 06:46:53 INFO: [No Data] Washington, DC
# 06:46:53 INFO: [No Data] Lewisetta, VA
# 06:46:53 INFO: [No Data] Sewells Point, VA
# 06:46:53 INFO: [No Data] Duck, NC
# 06:46:53 INFO: [No Data] Oregon Inlet Marina, NC
# 06:46:53 INFO: [No Data] Wrightsville Beach, NC
# 06:46:53 INFO: [No Data] Springmaid Pier, SC
# 06:46:53 INFO: [No Data] Oyster Landing (N Inlet Estuary), SC
# 06:46:53 INFO: [No Data] Charleston, SC
# 06:46:53 INFO: [No Data] Fort Pulaski, GA
# 06:46:53 INFO: [No Data] Fernandina Beach, FL
# 06:46:53 INFO: [No Data] Mayport (Bar Pilots Dock), FL
# 06:46:53 INFO: [No Data] I-295 Bridge, St Johns River, FL
# 06:46:53 INFO: [No Data] Trident Pier, FL
# 06:46:53 INFO: [No Data] Lake Worth Pier, FL
# 06:46:53 INFO: [No Data] Virginia Key, FL
# 06:46:53 INFO: [No Data] Vaca Key, FL
# 06:46:53 INFO: [No Data] Key West, FL
# 06:46:53 INFO: [No Data] Naples, FL
# 06:46:53 INFO: [No Data] Fort Myers, FL
# 06:46:53 INFO: [No Data] Port Manatee, FL
# 06:46:53 INFO: [No Data] Mckay Bay Entrance, FL
# 06:46:53 INFO: [No Data] Clearwater Beach, FL
# 06:46:53 INFO: [No Data] Cedar Key, FL
# 06:46:53 INFO: [No Data] Apalachicola, FL
# 06:46:53 INFO: [No Data] Panama City, FL
# 06:46:53 INFO: Finished processing [BTMPB]: http://oos.soest.hawaii.edu/thredds/dodsC/pacioos/hycom/global
# 06:46:55 WARNING: /home/filipe/miniconda/envs/SECOORA/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
#
# 06:47:11 INFO: 13.74 minutes
# 06:47:11 INFO: EOF
